# %%
from bs4 import BeautifulSoup
import urllib.request as urllib2
from urllib.request import urlopen
import re
import csv
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import itertools

count = 0
BASE = 'https://www.indeed.com/'
FIRST_LISTING_PAGE = 'https://www.indeed.com/cmp/Pnc-Financial-Services-Group/jobs?clearPrefilter=1'
LISTING_URL_PREFIX = 'https://www.indeed.com/cmp/Pnc-Financial-Services-Group/jobs?start='
LISTING_URL_POSTFIX = 'clearPrefilter=1#cmp-menu-container'


def scrape(postingUrl,bank):
    print(postingUrl)
    global count
    headers = ["Job No", "Institution", "List Id {1,2,3}", "URL (URL of the job posting)"]

    values = [count, "PNC Bank", "2", postingUrl]
    
    indices = list(range(1, 101))
    
    wordCountDict = dict.fromkeys(indices,0)
    postingDict = dict(zip(headers, values))
    
    #try:
    hdr = {"User-Agent":'Mozilla/5.0'}
    proxy_support = urllib2.ProxyHandler({"http":"10.10.1.10:3128"})
    opener = urllib2.build_opener(proxy_support)
    urllib2.install_opener(opener)
    req = urllib2.Request(postingUrl,headers=hdr)
    html_page = urlopen(req)
    soup2 =  BeautifulSoup(html_page,"html.parser")
    value = soup2.find('input', {'id':'preLoadJSON'})
    print(value)
            
        #dataDict = postingDict.copy()  
        #return {**postingDict, **wordCountDict}
    
    #except:
        #print("Exception")
        #return ("An exception occurred")
    
    count = count + 1

    dataDict = postingDict.copy()  
    return {**postingDict, **wordCountDict}

def scrape_page_pnc(page):
    response = urlopen(page)
    bs_obj = BeautifulSoup(response, "html.parser")
    if bs_obj:
        links = bs_obj.findAll('div',{'class': 'cmp-section cmp-with-border'})
        for page in links:
            linkTags = page.find_all('a', attrs={'href': re.compile("/cmp/_")})
            for tag in linkTags:
                link = tag.get('href')
                postingUrl = BASE + link
                pageDict = scrape(postingUrl,"PNC")
                break
                #if (type(pageDict) is dict):
                        #data = pd.DataFrame([pageDict])
                        # if file does not exist write header 
                        #if not os.path.isfile('pnc_desc.csv'):
                            #data.to_csv('pnc_desc.csv', header='column_names')
                        #else: 
                            # else it exists so append without writing the header
                            #data.to_csv('pnc_desc.csv', mode='a', header=False)
                #else:
                    #print("exception?")
            break

def scrape_site(Url):
    scrape_page_pnc(FIRST_LISTING_PAGE)
    for i in range(12,996,12):
        nextPageUrl = LISTING_URL_PREFIX +  str(i) + "&" + LISTING_URL_POSTFIX
        scrape_page_pnc(nextPageUrl)
        break

def get_data(bank,Url):
    scrape_site(Url)

if __name__ == '__main__':
    get_data("PNC","https://www.indeed.com/jobs?q=Pnc+Bank")
# Out:
# https://www.indeed.com//cmp/_/job?jk=46059cfe627fdc13&tk=1d467o8lsak93800
# <input capture-escaped-parsed-value="preloadResponse" id="preLoadJSON" type="hidden" value='{"SmartSearchJSONValue":null,"searchResultsResponse":null,"JobFieldsToDisplay":{"Position1":"autoreq","JobTitle":"jobtitle","Position3":["formtext7","formtext40","formtext5"],"Summary":"formtext57"},"JobsType":null,"HeaderInfo":[{"Name":"About PNC","Value":"https://www.pnc.com/en/about-pnc.html#.html"},{"Name":"Students \u0026 Graduates","Value":" https://www.pnc.com/en/about-pnc/careers/students.html"}],"ClientSettings":{"LoginType":"0","SSLEncrypt":"Yes","ProximitySearch":"Yes","RemoveApplyNow":"Yes","DefLocaleId":"1033","DefCountryId":"223","CandRemainsLoggedIn":"No","CandidateSelfDelete":"0","DisableJobCart":"no","DisableAgents":"No","SiteGeneralJobSubmissionType":"0","TimeOutSec":"600","SSOGateway":"0","EnableJobReferralStatusCheck":"Yes","EnableJobSubmissionWithdrawal":"No","PeriodMaxforSubmissionsOption":"3","MaxTotalReqSubmissionPerPeriod":"5","MaxConReqSubmission":"5","TGPasswordStrength":"Strong","GoDirectToLoginFromExternalURL":"no","EnablePostToMySocialNetworkLink":"no","EnableCommHistPage":"no","ShowSocMediaButtonsOnJobDetailsPage":"no","EnableSMIntegrationLogin":"no","GoogleDriveClientID":"","ProximityDefaultDistance":"20","ProximityDefaultMeasurement":"Miles","HideCreateAnAccountForThisGateway":"no","EnableTalentSuiteAuthentication":"No","MapsProviderforProximitysearch":"None","LoginDetailsManagement":"Enhanced","TGSecurityQuestionOverride":"3","HideKeywordSearchBox":"no","HideLocationSearchBox":"no","HideAdvancedSearch":"no","EnableSocialReferral":"no","ShowJobsNearMe":"no","ShowFeaturedJobs":"no","ShowMostRecentJobs":"no","HideHighlightedJobsSection":"yes","ResponsiveCandidateZone":"no","EnableMasterJobFeedIntegration":"no","Responsive":"false","TSEnvURLRef":"Old","EnableResponsiveCandidatePortal":"Yes","AdvancedSearchText":"Advanced Search","CandLandPageText":"\u003cb\u003e\u003cfont color= orange \u003eDisability Accommodation\u003c/b\u003e\u003c/font\u003e\u003cbr\u003eThe PNC workplace is inclusive and supportive of individual needs. If you have a physical or other impairment that might require an accommodation (including any technical assistance with the PNC Careers website or submission process), whether during the job application and hiring process or afterward if you are selected for a PNC position, please call 877-968-7762 and select Recruiting (option 4) or contact us via email at pathfinder@pnc.com. \u003cbr\u003e\u003cbr\u003eThe Human Resources Service Center hours of operation are Monday - Friday 9:00 AM to 5:00 PM ET.\u003cbr\u003e\u003cbr\u003eEEO Law Poster, a notice describing Federal equal employment opportunity laws can be viewed \u003ca href=\"http://www1.eeoc.gov/employers/upload/eeoc_self_print_poster.pdf\"\u003e\u003cb\u003e\u003cfont color= blue\u003ehere\u003c/font\u003e.\u003c/b\u003e\u003c/a\u003e\u003cbr\u003e\u003cbr\u003e\u003ca href=\"https://www.dol.gov/ofccp/regs/compliance/posters/pdf/OFCCP_EEO_Supplement_Final_JRF_QA_508c.pdf\"\u003e\u003cb\u003e\u003cfont color= blue\u003e EEO is the Law Supplemental\u003c/b\u003e\u003c/font\u003e \u003c/a\u003e\u003c/br\u003e\u003cbr\u003e\u003ca href=\"https://www.dol.gov/ofccp/pdf/pay-transp_unformattedESQA508c.pdf\"\u003e\u003cb\u003e\u003cfont color= blue\u003ePay Transparency Policy\u003c/b\u003e\u003c/font\u003e\u003c/a\u003e\u003cbr\u003e\u003cbr\u003e\u003cb\u003ePlease keep your selection to 5 job submissions for a seven (7) day time period.\u003c/b\u003e\u003cbr\u003e\u003cbr\u003eFor best results, search openings by selecting either Location(s) or Proximity Search by zip code\u003cbr\u003e\u003cbr\u003e\u003cb\u003eBased on answers to the questions on this page, the questions and options may change.\u003c/b\u003e","CNameURL":"","FeaturedJobsText":"Featured jobs","FiltersAppliedText":"Your selections: [#filternumber#]","HeaderCandidateZoneLinkText":"Candidate Zone","JobCounterIntroText":"Search from over [#jobcount#] opportunities","JobDet ...
# https://www.indeed.com//cmp/_/job?jk=2e2ba045ae97761e&tk=1d467odg9ak93800
# <input capture-escaped-parsed-value="preloadResponse" id="preLoadJSON" type="hidden" value='{"SmartSearchJSONValue":null,"searchResultsResponse":null,"JobFieldsToDisplay":{"Position1":"autoreq","JobTitle":"jobtitle","Position3":["formtext7","formtext40","formtext5"],"Summary":"formtext57"},"JobsType":null,"HeaderInfo":[{"Name":"About PNC","Value":"https://www.pnc.com/en/about-pnc.html#.html"},{"Name":"Students \u0026 Graduates","Value":" https://www.pnc.com/en/about-pnc/careers/students.html"}],"ClientSettings":{"LoginType":"0","SSLEncrypt":"Yes","ProximitySearch":"Yes","RemoveApplyNow":"Yes","DefLocaleId":"1033","DefCountryId":"223","CandRemainsLoggedIn":"No","CandidateSelfDelete":"0","DisableJobCart":"no","DisableAgents":"No","SiteGeneralJobSubmissionType":"0","TimeOutSec":"600","SSOGateway":"0","EnableJobReferralStatusCheck":"Yes","EnableJobSubmissionWithdrawal":"No","PeriodMaxforSubmissionsOption":"3","MaxTotalReqSubmissionPerPeriod":"5","MaxConReqSubmission":"5","TGPasswordStrength":"Strong","GoDirectToLoginFromExternalURL":"no","EnablePostToMySocialNetworkLink":"no","EnableCommHistPage":"no","ShowSocMediaButtonsOnJobDetailsPage":"no","EnableSMIntegrationLogin":"no","GoogleDriveClientID":"","ProximityDefaultDistance":"20","ProximityDefaultMeasurement":"Miles","HideCreateAnAccountForThisGateway":"no","EnableTalentSuiteAuthentication":"No","MapsProviderforProximitysearch":"None","LoginDetailsManagement":"Enhanced","TGSecurityQuestionOverride":"3","HideKeywordSearchBox":"no","HideLocationSearchBox":"no","HideAdvancedSearch":"no","EnableSocialReferral":"no","ShowJobsNearMe":"no","ShowFeaturedJobs":"no","ShowMostRecentJobs":"no","HideHighlightedJobsSection":"yes","ResponsiveCandidateZone":"no","EnableMasterJobFeedIntegration":"no","Responsive":"false","TSEnvURLRef":"Old","EnableResponsiveCandidatePortal":"Yes","AdvancedSearchText":"Advanced Search","CandLandPageText":"\u003cb\u003e\u003cfont color= orange \u003eDisability Accommodation\u003c/b\u003e\u003c/font\u003e\u003cbr\u003eThe PNC workplace is inclusive and supportive of individual needs. If you have a physical or other impairment that might require an accommodation (including any technical assistance with the PNC Careers website or submission process), whether during the job application and hiring process or afterward if you are selected for a PNC position, please call 877-968-7762 and select Recruiting (option 4) or contact us via email at pathfinder@pnc.com. \u003cbr\u003e\u003cbr\u003eThe Human Resources Service Center hours of operation are Monday - Friday 9:00 AM to 5:00 PM ET.\u003cbr\u003e\u003cbr\u003eEEO Law Poster, a notice describing Federal equal employment opportunity laws can be viewed \u003ca href=\"http://www1.eeoc.gov/employers/upload/eeoc_self_print_poster.pdf\"\u003e\u003cb\u003e\u003cfont color= blue\u003ehere\u003c/font\u003e.\u003c/b\u003e\u003c/a\u003e\u003cbr\u003e\u003cbr\u003e\u003ca href=\"https://www.dol.gov/ofccp/regs/compliance/posters/pdf/OFCCP_EEO_Supplement_Final_JRF_QA_508c.pdf\"\u003e\u003cb\u003e\u003cfont color= blue\u003e EEO is the Law Supplemental\u003c/b\u003e\u003c/font\u003e \u003c/a\u003e\u003c/br\u003e\u003cbr\u003e\u003ca href=\"https://www.dol.gov/ofccp/pdf/pay-transp_unformattedESQA508c.pdf\"\u003e\u003cb\u003e\u003cfont color= blue\u003ePay Transparency Policy\u003c/b\u003e\u003c/font\u003e\u003c/a\u003e\u003cbr\u003e\u003cbr\u003e\u003cb\u003ePlease keep your selection to 5 job submissions for a seven (7) day time period.\u003c/b\u003e\u003cbr\u003e\u003cbr\u003eFor best results, search openings by selecting either Location(s) or Proximity Search by zip code\u003cbr\u003e\u003cbr\u003e\u003cb\u003eBased on answers to the questions on this page, the questions and options may change.\u003c/b\u003e","CNameURL":"","FeaturedJobsText":"Featured jobs","FiltersAppliedText":"Your selections: [#filternumber#]","HeaderCandidateZoneLinkText":"Candidate Zone","JobCounterIntroText":"Search from over [#jobcount#] opportunities","JobDet ...

# %%
! pip install urllib2
# Out:
# Collecting urllib2
#   Could not find a version that satisfies the requirement urllib2 (from versions: )
# No matching distribution found for urllib2
# You are using pip version 19.0.1, however version 19.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
